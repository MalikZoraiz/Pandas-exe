# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('residence.csv')

# %%
df.head()
# Out:
#   year_month month_of_release     passenger_type direction citizenship  \
# 0    2001-09          2020-09  Long-term migrant  Arrivals          NZ
# 1    2002-03          2020-09  Long-term migrant  Arrivals          NZ
# 2    2005-01          2020-09  Long-term migrant  Arrivals          NZ
# 3    2005-04          2020-09  Long-term migrant  Arrivals          NZ
# 4    2005-07          2020-09  Long-term migrant  Arrivals          NZ
#
#                          visa country_of_residence  estimate  standard_error  \
# 0  NZ and Australian citizens          Afghanistan         1               0
# 1  NZ and Australian citizens          Afghanistan         3               0
# 2  NZ and Australian citizens          Afghanistan         5               0
# 3  NZ and Australian citizens          Afghanistan         1               0
# 4  NZ and Australian citizens          Afghanistan         1               0
#
#   status
# 0  Final
# 1  Final
# 2  Final
# 3  Final
# 4  Final

# %%
df[df['estimate']>5]
# Out:
#        year_month month_of_release     passenger_type direction citizenship  \
# 35        2010-06          2020-09  Long-term migrant  Arrivals          NZ
# 74        2015-12          2020-09  Long-term migrant  Arrivals          NZ
# 91        2018-12          2020-09  Long-term migrant  Arrivals          NZ
# 109       2021-08          2022-12  Long-term migrant  Arrivals          NZ
# 123       2001-01          2020-09  Long-term migrant  Arrivals          NZ
# ...           ...              ...                ...       ...         ...
# 324030    2023-05          2023-09  Long-term migrant  Arrivals      non-NZ
# 324031    2023-06          2023-09  Long-term migrant  Arrivals      non-NZ
# 324032    2023-07          2023-09  Long-term migrant  Arrivals      non-NZ
# 324033    2023-08          2023-09  Long-term migrant  Arrivals      non-NZ
# 324034    2023-09          2023-09  Long-term migrant  Arrivals      non-NZ
#
# ...

# %%
df[df['citizenship'] == "NZ"]
# Out:
#       year_month month_of_release     passenger_type direction citizenship  \
# 0        2001-09          2020-09  Long-term migrant  Arrivals          NZ
# 1        2002-03          2020-09  Long-term migrant  Arrivals          NZ
# 2        2005-01          2020-09  Long-term migrant  Arrivals          NZ
# 3        2005-04          2020-09  Long-term migrant  Arrivals          NZ
# 4        2005-07          2020-09  Long-term migrant  Arrivals          NZ
# ...          ...              ...                ...       ...         ...
# 45909    2023-02          2023-09  Long-term migrant  Arrivals          NZ
# 45910    2023-03          2023-09  Long-term migrant  Arrivals          NZ
# 45911    2023-06          2023-09  Long-term migrant  Arrivals          NZ
# 45912    2023-07          2023-09  Long-term migrant  Arrivals          NZ
# 45913    2023-08          2023-09  Long-term migrant  Arrivals          NZ
#
#                              visa country_of_residence  estimate  \
# ...

# %%
#AND & ---BOTH COND NEED TO BE TRUE
#OR  | ---EITHER COND NEED IS TRUE

# %%
df[(df['estimate']>5) & (df['citizenship'] == "NZ")]
# Out:
#       year_month month_of_release     passenger_type direction citizenship  \
# 35       2010-06          2020-09  Long-term migrant  Arrivals          NZ
# 74       2015-12          2020-09  Long-term migrant  Arrivals          NZ
# 91       2018-12          2020-09  Long-term migrant  Arrivals          NZ
# 109      2021-08          2022-12  Long-term migrant  Arrivals          NZ
# 123      2001-01          2020-09  Long-term migrant  Arrivals          NZ
# ...          ...              ...                ...       ...         ...
# 45815    2001-01          2020-09  Long-term migrant  Arrivals          NZ
# 45831    2002-10          2020-09  Long-term migrant  Arrivals          NZ
# 45833    2002-12          2020-09  Long-term migrant  Arrivals          NZ
# 45836    2003-04          2020-09  Long-term migrant  Arrivals          NZ
# 45902    2020-09          2022-01  Long-term migrant  Arrivals          NZ
#
# ...

# %%
df[(df['estimate']>5) | (df['citizenship'] == "NZ")]
# Out:
#        year_month month_of_release     passenger_type direction citizenship  \
# 0         2001-09          2020-09  Long-term migrant  Arrivals          NZ
# 1         2002-03          2020-09  Long-term migrant  Arrivals          NZ
# 2         2005-01          2020-09  Long-term migrant  Arrivals          NZ
# 3         2005-04          2020-09  Long-term migrant  Arrivals          NZ
# 4         2005-07          2020-09  Long-term migrant  Arrivals          NZ
# ...           ...              ...                ...       ...         ...
# 324030    2023-05          2023-09  Long-term migrant  Arrivals      non-NZ
# 324031    2023-06          2023-09  Long-term migrant  Arrivals      non-NZ
# 324032    2023-07          2023-09  Long-term migrant  Arrivals      non-NZ
# 324033    2023-08          2023-09  Long-term migrant  Arrivals      non-NZ
# 324034    2023-09          2023-09  Long-term migrant  Arrivals      non-NZ
#
# ...

# %%
df.head()
# Out:
#   year_month month_of_release     passenger_type direction citizenship  \
# 0    2001-09          2020-09  Long-term migrant  Arrivals          NZ
# 1    2002-03          2020-09  Long-term migrant  Arrivals          NZ
# 2    2005-01          2020-09  Long-term migrant  Arrivals          NZ
# 3    2005-04          2020-09  Long-term migrant  Arrivals          NZ
# 4    2005-07          2020-09  Long-term migrant  Arrivals          NZ
#
#                          visa country_of_residence  estimate  standard_error  \
# 0  NZ and Australian citizens          Afghanistan         1               0
# 1  NZ and Australian citizens          Afghanistan         3               0
# 2  NZ and Australian citizens          Afghanistan         5               0
# 3  NZ and Australian citizens          Afghanistan         1               0
# 4  NZ and Australian citizens          Afghanistan         1               0
#
#   status
# 0  Final
# 1  Final
# 2  Final
# 3  Final
# 4  Final

# %%
df[(df['citizenship'] == "non-NZ") | (df['citizenship'] == "NZ")]
# Out:
#        year_month month_of_release     passenger_type direction citizenship  \
# 0         2001-09          2020-09  Long-term migrant  Arrivals          NZ
# 1         2002-03          2020-09  Long-term migrant  Arrivals          NZ
# 2         2005-01          2020-09  Long-term migrant  Arrivals          NZ
# 3         2005-04          2020-09  Long-term migrant  Arrivals          NZ
# 4         2005-07          2020-09  Long-term migrant  Arrivals          NZ
# ...           ...              ...                ...       ...         ...
# 324030    2023-05          2023-09  Long-term migrant  Arrivals      non-NZ
# 324031    2023-06          2023-09  Long-term migrant  Arrivals      non-NZ
# 324032    2023-07          2023-09  Long-term migrant  Arrivals      non-NZ
# 324033    2023-08          2023-09  Long-term migrant  Arrivals      non-NZ
# 324034    2023-09          2023-09  Long-term migrant  Arrivals      non-NZ
#
# ...

# %%
df[df['citizenship'].isin(['NZ','non-NZ'])]
# Out:
#        year_month month_of_release     passenger_type direction citizenship  \
# 0         2001-09          2020-09  Long-term migrant  Arrivals          NZ
# 1         2002-03          2020-09  Long-term migrant  Arrivals          NZ
# 2         2005-01          2020-09  Long-term migrant  Arrivals          NZ
# 3         2005-04          2020-09  Long-term migrant  Arrivals          NZ
# 4         2005-07          2020-09  Long-term migrant  Arrivals          NZ
# ...           ...              ...                ...       ...         ...
# 324030    2023-05          2023-09  Long-term migrant  Arrivals      non-NZ
# 324031    2023-06          2023-09  Long-term migrant  Arrivals      non-NZ
# 324032    2023-07          2023-09  Long-term migrant  Arrivals      non-NZ
# 324033    2023-08          2023-09  Long-term migrant  Arrivals      non-NZ
# 324034    2023-09          2023-09  Long-term migrant  Arrivals      non-NZ
#
# ...
